# %%
import numpy as np

# %%
import heasoftpy

# %%
import os

path = "/Users/nickdahlen/miniforge3/envs/henv/heasoft/lib/python"
print([d for d in os.listdir(path) if "heasoft" in d.lower()])
# Out:
# ['heasoftpy']

# %%
import os

base = "/Users/nickdahlen/miniforge3/envs/henv/heasoft/lib/python"
print(os.listdir(base))
# Out:
# ['xspec', 'heasp.py', '__pycache__', 'heasoftpy', 'lib_heasp.dylib', '_heasp.so', 'mxspec']

# %%
print(os.listdir("/Users/nickdahlen/miniforge3/envs/henv/heasoft/lib/python/heasoftpy"))
# Out:
# ['demo', 'Xspec', 'heasim', 'nustar', 'calet', 'config.py', 'version.py', 'fcn.py', 'burstcube', 'heatools', 'suzaku', '__init__.py', 'core.py', '__pycache__', 'ixpe', 'attitude', 'ftools', 'heasptools', 'utils.py', 'swift', 'heagen', 'nicer', '_modules.py', 'hitomixrism', 'integral', 'heacore', 'maxi']
